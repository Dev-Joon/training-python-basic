# %% [markdown]
# # Matplotlib
# 다양한 형태의 그래프를 통해서 데이터 시각화를 할 수 있는 라이브러리

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. 그래프 기본

# %%
x = [1, 2, 3]
y = [2, 4, 8]
plt.plot(x, y)

# %%
print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x115adc730>]

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# ## Title 설정

# %%
plt.plot(x, y)
plt.title('Line Graph')
# Out:
# Text(0.5, 1.0, 'Line Graph')

# %%
plt.plot(x, y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44733 (\N{HANGUL SYLLABLE GGEOG}) missing from current font.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/events.py:89: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   func(*args, **kwargs)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44733 (\N{HANGUL SYLLABLE GGEOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 51008 (\N{HANGUL SYLLABLE EUN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 49440 (\N{HANGUL SYLLABLE SEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 44536 (\N{HANGUL SYLLABLE GEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 47000 (\N{HANGUL SYLLABLE RAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/anaconda3/envs/py39/lib/python3.9/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 54532 (\N{HANGUL SYLLABLE PEU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# ## 한글 폰트 설정

# %%
import matplotlib
# matplotlib.rcParams['font.family'] = 'Malgun Gothic' # Windows
matplotlib.rcParams['font.family'] = 'AppleGothic' # Mac
matplotlib.rcParams['font.size'] = 15 # 글자 크기
matplotlib.rcParams['axes.unicode_minus'] = False # 한글 폰트 사용 시, 마이너스 글자가 깨지는 현상을 해결

# %%
import matplotlib.font_manager as fm

fm.fontManager.ttflist # 사용 가능한 폰트 확인
[f.name for f in fm.fontManager.ttflist]
# Out:
# ['STIXSizeFourSym',
#  'STIXGeneral',
#  'DejaVu Sans',
#  'cmss10',
#  'STIXSizeOneSym',
#  'STIXNonUnicode',
#  'STIXGeneral',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'cmmi10',
#  'STIXNonUnicode',
#  'STIXSizeThreeSym',
#  'DejaVu Sans',
#  'STIXGeneral',
#  'DejaVu Serif Display',
#  'DejaVu Sans',
#  'DejaVu Serif',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'STIXNonUnicode',
#  'DejaVu Sans Display',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Sans Mono',
#  'STIXSizeTwoSym',
#  'STIXSizeTwoSym',
#  'cmr10',
#  'STIXGeneral',
#  'STIXSizeThreeSym',
#  'STIXSizeFiveSym',
#  'cmtt10',
#  'cmb10',
#  'STIXSizeOneSym',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'cmex10',
#  'cmsy10',
#  'STIXNonUnicode',
#  'Skia',
#  'STIXIntegralsSm',
#  'Bodoni Ornaments',
#  'Silom',
#  'Kokonor',
#  'Hiragino Sans',
#  'Chalkboard SE',
#  'Noto Sans Inscriptional Pahlavi',
#  'Noto Sans Adlam',
#  'STIXSizeThreeSym',
#  'STIXGeneral',
#  'PingFang HK',
#  'Beirut',
#  'Noto Sans Chakma',
#  'STIXSizeFourSym',
#  'Kohinoor Devanagari',
#  'Noto Sans Bassa Vah',
#  'Noto Sans Miao',
#  'Hiragino Sans',
#  'Muna',
#  'STIXSizeOneSym',
#  'System Font',
#  'Sinhala MN',
#  'Shree Devanagari 714',
#  'Courier New',
#  'Brush Script MT',
#  'PT Serif',
#  'Corsiva Hebrew',
#  'STIXIntegralsUpSm',
#  'Times',
#  'Noto Sans Lepcha',
#  'Farisi',
#  'Noto Sans Modi',
#  'STIXNonUnicode',
#  'Courier New',
#  'Bangla MN',
#  'Savoye LET',
#  'Noto Sans Sora Sompeng',
#  'Hoefler Text',
#  'STIXNonUnicode',
#  'Big Caslon',
#  'Noto Sans Marchen',
#  'American Typewriter',
#  'Noto Sans Bamum',
#  'Waseem',
#  'Noto Sans Tifinagh',
#  'Mishafi',
#  'STIXSizeOneSym',
#  'Arial',
#  '.SF NS Mono',
#  'Noto Serif Hmong Nyiakeng',
#  'Apple Braille',
#  'Noto Sans Lisu',
#  'Futura',
#  'KufiStandardGK',
#  'Wingdings 3',
#  'Superclarendon',
#  'Palatino',
#  'Noto Sans Duployan',
#  'Noto Sans Javanese',
#  'Papyrus',
#  'Galvji',
#  'Noto Sans Vai',
#  'Noto Serif Myanmar',
#  'Georgia',
#  'Courier New',
#  'Thonburi',
#  'Symbol',
#  'Party LET',
#  'Zapfino',
#  'STIXIntegralsUpD',
#  'Noto Sans Mandaic',
#  'Hiragino Maru Gothic Pro',
#  'Baghdad',
#  'Hiragino Sans',
#  'Noto Sans Glagolitic',
#  'Impact',
#  'Wingdings',
#  'Arial Unicode MS',
#  'Kohinoor Telugu',
#  'Sana',
#  'Noto Nastaliq Urdu',
#  '.New York',
#  'Noto Sans Lydian',
#  'Sathu',
#  'Raanana',
#  'Noto Sans Yi',
#  'Gill Sans',
#  'Tahoma',
#  'InaiMathi',
#  'Didot',
#  'Helvetica',
#  'Noto Sans Tai Le',
#  'Menlo',
#  'Noto Sans Carian',
#  'STIXSizeTwoSym',
#  'Noto Sans Rejang',
#  'Noto Sans Lycian',
#  'Mshtakan',
#  'Noto Sans Old Permic',
#  'Noto Sans Canadian Aboriginal',
#  'Noto Sans Egyptian Hieroglyphs',
#  'Marker Felt',
#  'Noto Sans Warang Citi',
#  'Noto Sans Pau Cin Hau',
#  'Noto Sans Ugaritic',
#  'Mishafi Gold',
#  'Noto Serif Ahom',
#  'Hiragino Sans',
#  'Noto Serif Yezidi',
#  'Noto Sans Myanmar',
#  'Charter',
#  'Damascus',
#  'Noto Sans Gothic',
#  'Noto Sans Old Turkic',
#  'Oriya Sangam MN',
#  'STIXIntegralsD',
#  'Noto Sans Meroitic',
#  'Hiragino Sans',
#  'Myanmar Sangam MN',
#  'Euphemia UCAS',
#  'Trebuchet MS',
#  'Courier New',
#  'Hiragino Mincho ProN',
#  'Arial Narrow',
#  'STIXIntegralsD',
#  'Gurmukhi MN',
#  'PT Serif Caption',
#  'Apple Chancery',
#  'AppleMyungjo',
#  'Noto Sans Sharada',
#  '.ThonburiUI',
#  'Chalkboard',
#  'Noto Sans Multani',
#  'Arial Narrow',
#  'ITF Devanagari',
#  'Noto Sans Psalter Pahlavi',
#  'Phosphate',
#  'Noto Sans Masaram Gondi',
#  'Rockwell',
#  'Al Tarikh',
#  'Noto Sans Cuneiform',
#  'Krungthep',
#  'Noto Sans Takri',
#  'Noto Serif Balinese',
#  'Kefa',
#  'Sinhala Sangam MN',
#  'Noto Sans Tirhuta',
#  'Hoefler Text',
#  'Georgia',
#  'Kailasa',
#  'Bodoni 72 Smallcaps',
#  'Herculanum',
#  'Apple Braille',
#  'STIXNonUnicode',
#  'Trebuchet MS',
#  'Noto Sans Old South Arabian',
#  'Noto Sans Newa',
#  'STIXSizeTwoSym',
#  '.SF Arabic',
#  'Noto Sans Kharoshthi',
#  'Georgia',
#  'Devanagari Sangam MN',
#  'AppleGothic',
#  'Microsoft Sans Serif',
#  'Songti SC',
#  'Avenir Next',
#  'Courier',
#  'Kohinoor Gujarati',
#  'Noto Sans Kannada',
#  'STIXGeneral',
#  'Noto Sans Caucasian Albanian',
#  'Noto Sans Oriya',
#  'DIN Alternate',
#  'Noto Sans Inscriptional Parthian',
#  'Noto Sans Avestan',
#  'Noto Sans Armenian',
#  'Noto Sans Mro',
#  '.SF Arabic Rounded',
#  'Noto Sans Phoenician',
#  'Noto Sans Osmanya',
#  'Farah',
#  'Noto Sans NKo',
#  'Arial Unicode MS',
#  'Noto Sans Brahmi',
#  'STIX Two Text',
#  'Apple Symbols',
#  'Arial',
#  '.Keyboard',
#  'Noto Sans Buginese',
#  'Times New Roman',
#  '.SF Compact',
#  'Noto Sans Kaithi',
#  'Myanmar MN',
#  'Al Bayan',
#  'Diwan Kufi',
#  'Sukhumvit Set',
#  'Noteworthy',
#  'Gujarati Sangam MN',
#  'Noto Sans Kayah Li',
#  'STIXIntegralsUp',
#  'Bodoni 72 Oldstyle',
#  'Avenir',
#  'Noto Sans Tagalog',
#  'Noto Sans Hanifi Rohingya',
#  'Noto Sans Hanunoo',
#  'Noto Sans Meetei Mayek',
#  'Times New Roman',
#  'Noto Sans Mahajani',
#  'Verdana',
#  'Helvetica Neue',
#  'Kannada MN',
#  'Noto Sans Imperial Aramaic',
#  'Noto Sans Manichaean',
#  'Seravek',
#  'Academy Engraved LET',
#  'Trebuchet MS',
#  '.SF NS Mono',
#  'Avenir Next Condensed',
#  'Copperplate',
#  'Noto Sans Ol Chiki',
#  'Malayalam Sangam MN',
#  'STIXNonUnicode',
#  'Verdana',
#  'Tamil MN',
#  'Chalkduster',
#  'Apple Braille',
#  'Noto Sans Syriac',
#  'Lao MN',
#  'STIX Two Math',
#  'PT Mono',
#  'Times New Roman',
#  'Verdana',
#  '.SF NS Rounded',
#  'STIXSizeThreeSym',
#  'Tahoma',
#  'Mukta Mahee',
#  'Snell Roundhand',
#  'Verdana',
#  'Noto Sans Elbasan',
#  'STIXVariants',
#  'Noto Sans Old North Arabian',
#  'Devanagari MT',
#  'STIXVariants',
#  'Trebuchet MS',
#  'Noto Sans Batak',
#  'Heiti TC',
#  'System Font',
#  'STIXIntegralsUp',
#  'Hiragino Sans',
#  'Gujarati MT',
#  'Georgia',
#  'New Peninim MT',
#  'Noto Sans Linear A',
#  'Tamil Sangam MN',
#  'Noto Sans Siddham',
#  'Noto Sans Nabataean',
#  'Bodoni 72',
#  'Arial Black',
#  'Arial',
#  'Apple SD Gothic Neo',
#  '.New York',
#  'Noto Sans Thaana',
#  'Andale Mono',
#  'Wingdings 2',
#  'Malayalam MN',
#  'Noto Sans Tai Tham',
#  'Hiragino Sans GB',
#  'Noto Sans Khudawadi',
#  'Khmer Sangam MN',
#  'Noto Sans Cham',
#  'Comic Sans MS',
#  'Arial Narrow',
#  'Marion',
#  'Plantagenet Cherokee',
#  'Noto Sans Tagbanwa',
#  'Hiragino Sans',
#  'Arial Hebrew',
#  'Diwan Thuluth',
#  'Noto Sans PhagsPa',
#  'Monaco',
#  'Telugu Sangam MN',
#  'Gurmukhi Sangam MN',
#  'Arial Narrow',
#  'Noto Sans Palmyrene',
#  'Athelas',
#  'Oriya MN',
#  'Telugu MN',
#  'PT Sans',
#  'Times New Roman',
#  'Noto Sans Samaritan',
#  'Iowan Old Style',
#  'STIXGeneral',
#  'Arial Rounded MT Bold',
#  'Noto Sans Osage',
#  'Lao Sangam MN',
#  'STIXIntegralsSm',
#  'Apple Braille',
#  'Baskerville',
#  'DecoType Naskh',
#  'Kohinoor Bangla',
#  'Noto Sans Old Persian',
#  'Luminari',
#  'STIXSizeFourSym',
#  'Bangla Sangam MN',
#  'Apple Braille',
#  'STIXIntegralsUpSm',
#  'Webdings',
#  'Hiragino Sans',
#  '.SF Compact',
#  'Noto Sans Pahawh Hmong',
#  'Lucida Grande',
#  'Al Nile',
#  'Noto Sans Saurashtra',
#  '.Aqua Kana',
#  'Heiti TC',
#  '.SF Compact Rounded',
#  'Trattatello',
#  'STIXSizeFiveSym',
#  'Khmer MN',
#  'Geeza Pro',
#  'Cochin',
#  'Noto Sans Khojki',
#  'Kannada Sangam MN',
#  'Noto Sans New Tai Lue',
#  'Nadeem',
#  'Ayuthaya',
#  'Optima',
#  'STIX Two Text',
#  'Hiragino Sans',
#  'Noto Sans Wancho',
#  'Noto Sans Linear B',
#  'Noto Sans Gunjala Gondi',
#  'SignPainter',
#  'STIXIntegralsUpD',
#  'Noto Sans Hatran',
#  'Geneva',
#  'Noto Sans Coptic',
#  'DIN Condensed',
#  'Zapf Dingbats',
#  'Bradley Hand',
#  'Noto Sans Limbu',
#  'Noto Sans Old Italic',
#  'Noto Sans Old Hungarian',
#  'Noto Sans Sundanese',
#  'Comic Sans MS',
#  'Noto Sans Tai Viet',
#  'Noto Sans Mende Kikakui',
#  'Noto Sans Bhaiksuki',
#  'Noto Sans Buhid',
#  'Arial',
#  'Noto Sans Mongolian',
#  'Noto Sans Cypriot',
#  'Hiragino Sans',
#  'Noto Sans Syloti Nagri',
#  'Gurmukhi MT',
#  'STIXGeneral']

# %%
plt.plot(x, y)
plt.title('꺽은선 그래프')
# Out:
# Text(0.5, 1.0, '꺽은선 그래프')

# %%
plt.plot([-1, 0, 1], [-5, -1, 2])
